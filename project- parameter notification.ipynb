# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime,date,timedelta

# %%
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email import encoders
import smtplib

# %%
to_date= date.today()
file_date = to_date.strftime('%Y%m%d')
print(file_date)
file_name = r"C:\Users\pbann\OneDrive\Desktop\science\data_set\pawan_" + file_date + ".csv"
print(file_name)
df = pd.read_csv(r'C:\Users\pbann\OneDrive\Desktop\science\data set\pawan.csv')
# Out:
# 20220501
# C:\Users\pbann\OneDrive\Desktop\science\data_set\pawan_20220501.csv

# %%
df
# Out:
#      Observation Date (UTC+05:30)  \
# 0                01-05-2022 06:56
# 1                01-05-2022 07:06
# 2                01-05-2022 07:16
# 3                01-05-2022 07:26
# 4                01-05-2022 07:36
# ...                           ...
# 4459             02-05-2022 06:06
# 4460             02-05-2022 06:16
# 4461             02-05-2022 06:26
# 4462             02-05-2022 06:36
# 4463             02-05-2022 06:46
#
#       MOTOR_IB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT004) Actual  \
# 0                                             49.837318
# 1                                             50.011948
# 2                                             49.951386
# 3                                             50.054424
# 4                                             50.077065
# ...                                                 ...
# 4459                                          74.539391
# 4460                                          74.946716
# ...

# %%
df.columns
# Out:
# Index(['Observation Date (UTC+05:30)',
#        'MOTOR_IB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT004) Actual',
#        'MOTOR_OB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT005) Actual', 'Unnamed: 3',
#        'MOTOR_DE_BRG_MTL_TEMP (DIL2.20HNC32CT005) Actual',
#        'MOTOR_NDE_BRG_MTL_TEMP (DIL2.20HNC32CT006) Actual', 'Unnamed: 6',
#        'PUMP_IB_BRG_MTL_TEMP_1 (DIL2.20LAJ20CT027) Actual',
#        'PUMP_OB_BRG_MTL_TEMP_1 (DIL2.20LAJ20CT028) Actual'],
#       dtype='object')

# %%
df1 =  df[['Observation Date (UTC+05:30)','MOTOR_IB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT004) Actual','MOTOR_OB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT005) Actual']]

# %%
df1
# Out:
#      Observation Date (UTC+05:30)  \
# 0                01-05-2022 06:56
# 1                01-05-2022 07:06
# 2                01-05-2022 07:16
# 3                01-05-2022 07:26
# 4                01-05-2022 07:36
# ...                           ...
# 4459             02-05-2022 06:06
# 4460             02-05-2022 06:16
# 4461             02-05-2022 06:26
# 4462             02-05-2022 06:36
# 4463             02-05-2022 06:46
#
#       MOTOR_IB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT004) Actual  \
# 0                                             49.837318
# 1                                             50.011948
# 2                                             49.951386
# 3                                             50.054424
# 4                                             50.077065
# ...                                                 ...
# 4459                                          74.539391
# 4460                                          74.946716
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4464, step=1)

# %%
for i in df1.index:
    #print(df1.iloc[i]['Observation Date (UTC+05:30)'],df1.iloc[i]['MOTOR_IB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT004) Actual'])
    if df1.iloc[i]['MOTOR_IB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT004) Actual'] > 65:
        print(df1.iloc[i]['Observation Date (UTC+05:30)'],df1.iloc[i]['MOTOR_IB_BRG_MTL_TEMP_1 (DIL2.20HFC30CT004) Actual'])
# Out:
# 1/25/2022 1:06:10 PM 75.26268005
# 1/25/2022 1:16:10 PM 78.66073608
# 1/25/2022 1:26:10 PM 78.70018005
# 1/25/2022 1:36:10 PM 75.39105225
# 1/25/2022 1:46:05 PM 74.51194763
# 1/25/2022 1:56:10 PM 74.0187912
# 1/25/2022 2:06:10 PM 73.372612
# 1/25/2022 2:16:10 PM 73.38798523
# 1/25/2022 2:26:10 PM 73.37477112
# 1/25/2022 2:36:10 PM 73.46592712
# 1/25/2022 2:46:05 PM 73.61143494
# 1/25/2022 2:56:05 PM 73.78780365
# 1/25/2022 3:06:10 PM 73.80150604
# 1/25/2022 3:16:10 PM 73.99458313
# 1/25/2022 3:26:10 PM 73.90808105
# 1/25/2022 3:36:10 PM 73.91368103
# 1/25/2022 3:46:00 PM 73.99830627
# 1/25/2022 3:56:05 PM 73.94443512
# 1/25/2022 4:06:00 PM 74.29312897
# 1/25/2022 4:16:00 PM 73.88562012
# 1/25/2022 4:26:05 PM 73.79603577
# 1/25/2022 4:36:00 PM 74.16471863
# 1/25/2022 4:46:00 PM 73.89056396
# 1/25/2022 4:56:00 PM 73.25312805
# 1/25/2022 5:06:05 PM 68.32510376
# 1/25/2022 5:16:00 PM 67.93392181
# 1/25/2022 5:26:00 PM 67.41540527
# 1/25/2022 5:36:05 PM 68.28535461
# ...

# %%
def send_mail(_from, _to, _cc, _subj, _body, m_files):
    try:
        msg = MIMEMultipart()
        msg.attach(MIMEText(_body, 'plain'))
        msg['Subject'] = _subj
        msg['From'] = _from
        msg['To'] = ', '.join(_to)
        msg['Cc'] = ', '.join(_cc)
        s = gmail_server_connection()
        if len(m_files) != 0:
            for file in m_files:
                if os.path.isfile(file):
                    part = MIMEBase('application', 'octet-stream')
                    part.set_payload(open(file, "rb").read())
                    encoders.encode_base64(part)
                    file_name = os.path.basename(file)
                    part.add_header('Content-Disposition', 'attachment', filename=file_name)
                    msg.attach(part)
        s.sendmail(from_addr=_from, to_addrs=_to+_cc, msg=msg.as_string())
        s.quit()
    except Exception as e:
        #logger.error("Unable to send mail" + str(e))
        #sys.exit(1)
        print(e)

# %%
def gmail_server_connection():
    user_mail = 'pbannuru@gmail.com'
    password = 'pavan@555'
    s = smtplib.SMTP('smtp.gmail.com:587')
    s.ehlo()
    s.starttls()
    s.login(user=user_mail, password=password)
    return s

# %%
send_mail(_from = 'pbannuru@gmail.com', _to = ['pbannuru@gmail.com'], _cc = ['pbannuru@gmail.com'], _subj = 'mill_temp', _body = 'test', m_files="")
# Out:
# (534, b'5.7.9 Application-specific password required. Learn more at\n5.7.9  https://support.google.com/mail/?p=InvalidSecondFactor z10-20020a17090ab10a00b001d792761e2esm17461165pjq.47 - gsmtp')

# %%
import smtplib

server = smtplib.SMTP('smtp.gmail.com:587')
server.starttls()
server.login('pbannuru@gmail.com','pavan@555')
server.sendmail('pbannuru@gmail.com','pavankumarbannuru@gmail.com','mail sent')
print('mail sent')
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27136/720023999.py in <module>
#       3 server = smtplib.SMTP('smtp.gmail.com:587')
#       4 server.starttls()
# ----> 5 server.login('pbannuru@gmail.com','pavan@555')
#       6 server.sendmail('pbannuru@gmail.com','pavankumarbannuru@gmail.com','mail sent')
#       7 print('mail sent')
#
# ~\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     748
#     749         # We could not login successfully.  Return result of last attempt.
# --> 750         raise last_exception
#     751
#     752     def starttls(self, keyfile=None, certfile=None, context=None):
#
# ~\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     737             method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738             try:
# ...
